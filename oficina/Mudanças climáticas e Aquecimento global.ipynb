# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show

from warnings import filterwarnings
filterwarnings("ignore")

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a859dbb8-aa6d-43ac-b7b7-1c1e8591c546">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Dados Meteorológicos
#
# fonte: http://www.inmet.gov.br/portal/index.php?r=bdmep/bdmep

# %%
data_meteorologia = pd.read_csv("../dados/historico_tempo_curado.csv", sep=";")

# %%
temp_max = data_meteorologia.TempMaximaMedia
temp_min = data_meteorologia.TempMinimaMedia
periodo = data_meteorologia.Data

temp = figure(plot_width=900, plot_height=300,
            x_range=periodo.tolist(), title="temp. min")

temp.line(periodo, temp_min, color="navy")
temp.line(periodo, temp_max, color="darkred")

show(temp)

# %%
data_meteorologia.head()

# %% [markdown]
# # Dados climáticos
#
# fonte temperatura oceânica: http://data.okfn.org/data/core/global-temp

# %%
data_ocean = pd.read_csv("../dados/annual_ocean_temp.csv")

# %%
x1 = data_ocean.Year
y1 = data_ocean.Mean

ocean = figure(plot_width=750, plot_height=400, x_axis_label = "Year", y_axis_label = "Mean", title="temp oceânica")
ocean.scatter(x1, y1, color="darkcyan")
show(ocean)

# %% [markdown]
# <video src="../aulas/aula1/media/Complete_TAVG_Annual.webm" controls width="620" height="480" preload="auto"></video>
#
# fonte: http://berkeleyearth.org/data/

# %% [markdown]
# # Emissão de $CO_2$
#
# fonte: http://cdiac.ornl.gov/ftp/ndp030/CSV-FILES/

# %%
co2 = pd.read_csv("../dados/co2_por_nacao.csv")

# %%
co2.columns
# Out:
# Index(['Nation', 'Year',
#        'Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)',
#        'Emissions from solid fuel consumption',
#        'Emissions from liquid fuel consumption',
#        'Emissions from gas fuel consumption',
#        'Emissions from cement production', 'Emissions from gas flaring',
#        'Per capita CO2 emissions (metric tons of carbon)',
#        'Emissions from bunker fuels (not included in the totals)'],
#       dtype='object')

# %%
n = ""
for i in co2.Nation:
    if i != n:
        print(i)
    n = i
# Out:
# AFGHANISTAN
# ALBANIA
# ALGERIA
# ANDORRA
# ANGOLA
# ANGUILLA
# ANTARCTIC FISHERIES
# ANTIGUA & BARBUDA
# ARGENTINA
# ARMENIA
# ARUBA
# AUSTRALIA
# AUSTRIA
# AZERBAIJAN
# BAHAMAS
# BAHRAIN
# BANGLADESH
# BARBADOS
# BELARUS
# BELGIUM
# BELIZE
# BENIN
# BERMUDA
# BHUTAN
# BONAIRE, SAINT EUSTATIUS, AND SABA
# BOSNIA & HERZEGOVINA
# BOTSWANA
# BRAZIL
# BRITISH VIRGIN ISLANDS
# BRUNEI (DARUSSALAM)
# BULGARIA
# BURKINA FASO
# BURUNDI
# CAMBODIA
# CANADA
# CAPE VERDE
# CAYMAN ISLANDS
# CENTRAL AFRICAN REPUBLIC
# CHAD
# CHILE
# CHINA (MAINLAND)
# CHRISTMAS ISLAND
# COLOMBIA
# COMOROS
# CONGO
# OCCUPIED PALESTINIAN TERRITORY
# OMAN
# PACIFIC ISLANDS (PALAU)
# PAKISTAN
# PALAU
# PANAMA
# PAPUA NEW GUINEA
# PARAGUAY
# PENINSULAR MALAYSIA
# PERU
# PHILIPPINES
# PLURINATIONAL STATE OF BOLIVIA
# POLAND
# PORTUGAL
# PUERTO RICO
# QATAR
# REPUBLIC OF CAMEROON
# REPUBLIC OF KOREA
# REPUBLIC OF MOLDOVA
# REPUBLIC OF SOUTH SUDAN
# REPUBLIC OF SOUTH VIETNAM
# REPUBLIC OF SUDAN
# REUNION
# RHODESIA-NYASALAND
# ROMANIA
# RUSSIAN FEDERATION
# RWANDA
# RWANDA-URUNDI
# RYUKYU ISLANDS
# SABAH
# SAINT HELENA
# SAINT LUCIA
# SAINT MARTIN (DUTCH PORTION)
# SAMOA
# SAO TOME & PRINCIPE
# SARAWAK
# SAUDI ARABIA
# SENEGAL
# SERBIA
# SEYCHELLES
# SIERRA LEONE
# SINGAPORE
# SLOVAKIA
# SLOVENIA
# SOLOMON ISLANDS
# SOMALIA
# SOUTH AFRICA
# SPAIN
# SRI LANKA
# ST. KITTS-NEVIS
# ST. KITTS-NEVIS-ANGUILLA
# ST. PIERRE & MIQUELON
# ST. VINCENT & THE GRENADINES
# SUDAN
# SURINAME
# SWAZILAND
# SWEDEN
# SWITZERLAND
# SYRIAN ARAB REPUBLIC
# TAIWAN
# TAJIKISTAN
# TANGANYIKA
# THAILAND
# TIMOR-LESTE (FORMERLY EAST TIMOR)
# TOGO
# TONGA
# TRINIDAD AND TOBAGO
# TUNISIA
# TURKEY
# TURKMENISTAN
# TURKS AND CAICOS ISLANDS
# UGANDA
# UKRAINE
# UNITED ARAB EMIRATES
# UNITED KINGDOM
# UNITED KOREA
# UNITED REPUBLIC OF TANZANIA
# UNITED STATES OF AMERICA
# URUGUAY
# USSR
# UZBEKISTAN
# VANUATU
# VENEZUELA
# VIET NAM
# WALLIS AND FUTUNA ISLANDS
# YEMEN
# YUGOSLAVIA (FORMER SOCIALIST FEDERAL REPUBLIC)
# YUGOSLAVIA (MONTENEGRO & SERBIA)
# ZAMBIA
# ZANZIBAR
# ZIMBABWE

# %%
indicador = 'Per capita CO2 emissions (metric tons of carbon)'

paises = ["BRAZIL", "JAPAN", "HAITI"]
colors = ["green", "purple", "blue"]

p_co2 = figure(plot_width=900, plot_height=250, title=indicador)

for i, j in zip(paises, colors):
    pais = co2[co2.Nation==i]
    p_co2.line(pais["Year"],
               pais[indicador],
               color=j, legend=i)
    
p_co2.legend.orientation="horizontal"
p_co2.legend.background_fill_alpha = 0
show(p_co2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6b1ee408-33da-42a2-b4aa-d30c7acca58d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6b1ee408-33da-42a2-b4aa-d30c7acca58d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6b1ee408-33da-42a2-b4aa-d30c7acca58d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '
type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"4f433c99-75cf-432e-a9ba-a6ea1c7a8f54","subtype":"Figure","type":"Plot"},"ticker":{"id":"c5739bb4-23a6-420a-a98f-4d961352ce9a","type":"BasicTicker"}},"id":"e796ff6a-9470-4e66-aecf-0e28377604a1","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"56fe620a-b995-4731-ae91-dee6387bbc68","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"4f433c99-75cf-432e-a9ba-a6ea1c7a8f54","subtype":"Figure","type":"Plot"}},"id":"9669f181-4838-4a6a-8eaf-b1c9a8573e58","type":"PanTool"},{"attributes":{"plot":{"id":"4f433c99-75cf-432e-a9ba-a6ea1c7a8f54","subtype":"Figure","type":"Plot"}},"id":"bb09b507-dcd7-4712-97c7-4fd22e6321ce","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"56fe620a-b995-4731-ae91-dee6387bbc68","type":"BoxAnnotation"},"plot":{"id":"4f433c99-75cf-432e-a9ba-a6ea1c7a8f54","subtype":"Figure","type":"Plot"}},"id":"70811b87-8812-4028-bcd7-04c211e7f3f5","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"4f433c99-75cf-432e-a9ba-a6ea1c7a8f54","subtype":"Figure","type":"Plot"}},"id":"2b1000a1-e7ae-49a7-950a-587e93d52305","type":"SaveTool"},{"attributes":{"plot":{"id":"4f433c99-75cf-432e-a9ba-a6ea1c7a8f54","subtype":"Figure","type":"Plot"}},"id":"1f597966-7985-4ac3-997c-7f ...

# %%
from sklearn.svm import SVR

x = "Year"
y = "Per capita CO2 emissions (metric tons of carbon)"

país = co2[co2.Nation=="BRAZIL"][[x, y]]

país_data = país[país.Year>1949]
X = país_data[x].values.reshape(-1, 1)
Y = país_data[y].values.reshape(-1, 1)

reg = SVR(kernel="linear")
results = reg.fit(X, Y).predict(X).reshape(-1,1)

p_nation = figure(plot_width=500, plot_height=300, x_axis_label = x, title=y)
p_nation.scatter(país[x], país[y])
p_nation.line(x=país_data[x], y=results.tolist(), line_width=2, line_color="darkorange")
show(p_nation)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3ec31029-8474-4401-94b8-633a6b9566b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3ec31029-8474-4401-94b8-633a6b9566b4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3ec31029-8474-4401-94b8-633a6b9566b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3ec31029-8474-4401-94b8-633a6b9566b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cc523bf3-d330-44c0-b41a-af9056f9964f":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"52b11a8a-119b-4c11-81cc-da93e8dce4ea","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"}},"id":"f2709d43-5387-488b-ae7b-b6bdb0ffb628","type":"PanTool"},{"attributes":{"line_color":{"value":"darkorange"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"15536972-44d8-4c5c-adfe-2ead85b880c6","type":"Line"},{"attributes":{"plot":{"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"}},"id":"ad23d302-ddaa-4aba-bb86-4af20b336c84","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"52b11a8a-119b-4c11-81cc-da93e8dce4ea","type":"BoxAnnotation"},"plot":{"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"}},"id":"4478871a-dec4-41fb-a504-ffe4c7afead5","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"}},"id":"bbd88eec-345e-4aca-8104-e513f07759fd","type":"SaveTool"},{"attributes":{"plot":{"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"}},"id":"2af6b116-15aa-405a-b69b-9e453b620959","type":"ResetTool"},{"attributes":{"plot":{"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"}},"id":"dcda3ce0-7531-42c5-bf88-578652e608d7","type":"HelpTool"},{"attributes":{},"id":"7efbc0f4-125c-4a03-8b0c-7459c0fe9182","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"4a0c9c6a-9d2f-4ae9-85d6-49ec98a1f4c4","type":"ColumnDataSource"},"glyph":{"id":"15536972-44d8-4c5c-adfe-2ead85b880c6","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f47162f4-1af6-45b4-b2f6-b7fa9b947d61","type":"Line"},"selection_glyph":null},"id":"b273957e-a521-405a-bf85-9493dc1433cb","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f47162f4-1af6-45b4-b2f6-b7fa9b947d61","type":"Line"},{"attributes":{"below":[{"id":"2727599d-b98d-4879-80a7-19b7194cc1e4","type":"LinearAxis"}],"left":[{"id":"cec8334a-859d-49dc-ba15-271d4874c794","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"2727599d-b98d-4879-80a7-19b7194cc1e4","type":"LinearAxis"},{"id":"c8152378-d7c6-4605-806b-8786630ba39e","type":"Grid"},{"id":"cec8334a-859d-49dc-ba15-271d4874c794","type":"LinearAxis"},{"id":"1e19eb2e-a4b1-4a48-9ce1-d9e5b1c6acb3","type":"Grid"},{"id":"52b11a8a-119b-4c11-81cc-da93e8dce4ea","type":"BoxAnnotation"},{"id":"48e5dbca-fa0c-4cdc-b166-c81366b7d937","type":"GlyphRenderer"},{"id":"b273957e-a521-405a-bf85-9493dc1433cb","type":"GlyphRenderer"}],"title":{"id":"d89cf545-a003-43a3-995b-644920fdbfba","type":"Title"},"tool_events":{"id":"18081417-8a4f-4b1b-952f-223516897472","type":"ToolEvents"},"toolbar":{"id":"7a130c07-0365-4d5a-a745-3a2ed4a1899b","type":"Toolbar"},"x_range":{"id":"aef49288-74a6-463e-bb34-e1768e0ff64d","type":"DataRange1d"},"y_range":{"id":"07d0b284-5ce3-4e6a-a64d-a80089313b8e","type":"DataRange1d"}},"id":"66a34463-c6f4-4647-9b6b-a0a2dba55a5a","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"5615d79a-1ac4-4fd5-b533-9595bda49bd8","type":"ColumnDataSource"},"glyph":{"id":"b0044013-6a88-4cfd-97f7-2ddfb8ddb29e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"a0559348-1d37-4591-b52a-4f3b2692c206","type":"Circle"},"selection_glyph":null},"id":"48e5dbca-fa0c-4cdc-b166-c81366b7d937","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,19 ...
