# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
import csv
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ea6fdbef-5d3b-4123-9415-401ff8a1fb4e">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv("../dados/co2_por_nacao.csv")
data.columns
# Out:
# Index(['Nation', 'Year',
#        'Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)',
#        'Emissions from solid fuel consumption',
#        'Emissions from liquid fuel consumption',
#        'Emissions from gas fuel consumption',
#        'Emissions from cement production', 'Emissions from gas flaring',
#        'Per capita CO2 emissions (metric tons of carbon)',
#        'Emissions from bunker fuels (not included in the totals)'],
#       dtype='object')

# %%
x = "Year"
y = "Per capita CO2 emissions (metric tons of carbon)"

# %%
brasil = data[data.Nation=="BRAZIL"][[x, y]]

# %%
p = figure(plot_width=500, plot_height=300, x_axis_label = x, title=y)
p.scatter(brasil[x], brasil[y])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d0ff8fd-7a23-4127-aad5-6cc94e255e4a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0d0ff8fd-7a23-4127-aad5-6cc94e255e4a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d0ff8fd-7a23-4127-aad5-6cc94e255e4a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d0ff8fd-7a23-4127-aad5-6cc94e255e4a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3a82df27-c574-447f-ae65-bce2965b6b8a":{"roots":{"references":[{"attributes":{"plot":{"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"}},"id":"0ac2d413-dac3-4f92-87ed-91f4a530d6a8","type":"PanTool"},{"attributes":{"data_source":{"id":"529677a0-89b7-4b8b-ab6f-a2971c81f7ae","type":"ColumnDataSource"},"glyph":{"id":"622a89b2-8e16-4ff4-8f49-7456f7ecf421","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"397959a0-257c-4540-ae1a-6c289226d873","type":"Circle"},"selection_glyph":null},"id":"1fa5e105-35a2-4a2a-a771-66ee5f62424a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"}},"id":"82d222fb-5d9a-424e-8f80-c44efcc05186","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"d2030330-6a15-4128-946d-f6b977302263","type":"BoxAnnotation"},"plot":{"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"}},"id":"2180f49d-da33-463d-8f98-d0094e2321bb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"}},"id":"6b4f1dfb-fb2f-4760-9d8d-39a4e29c15ce","type":"SaveTool"},{"attributes":{"plot":{"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"}},"id":"d4e28d81-9f8e-400a-8d40-3e3096e299bc","type":"ResetTool"},{"attributes":{},"id":"e17c02cd-ed50-476f-982f-d13c5035977c","type":"BasicTickFormatter"},{"attributes":{},"id":"ebdf02a5-28d9-4a38-905d-74ffde5ec228","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"6f3a6b95-0be0-4144-9b43-d01855d59068","type":"LinearAxis"}],"left":[{"id":"7aba017c-1482-449e-91ce-714185e64045","type":"LinearAxis"}],"plot_height":300,"plot_width":500,"renderers":[{"id":"6f3a6b95-0be0-4144-9b43-d01855d59068","type":"LinearAxis"},{"id":"91df1f5f-14c0-48b7-bae4-387b6326beb8","type":"Grid"},{"id":"7aba017c-1482-449e-91ce-714185e64045","type":"LinearAxis"},{"id":"2f23497d-e762-43e0-8149-7ed97bb99f44","type":"Grid"},{"id":"d2030330-6a15-4128-946d-f6b977302263","type":"BoxAnnotation"},{"id":"1fa5e105-35a2-4a2a-a771-66ee5f62424a","type":"GlyphRenderer"}],"title":{"id":"d00cf7cc-acb4-4101-aba2-3c664adde376","type":"Title"},"tool_events":{"id":"17b3575d-ed8d-4a63-890e-01ba2c879aff","type":"ToolEvents"},"toolbar":{"id":"27dcba1c-ff2f-44ec-ad58-4431b72dcd08","type":"Toolbar"},"x_range":{"id":"3c398ecb-a9fb-423f-9af0-6077f2dd6bde","type":"DataRange1d"},"y_range":{"id":"d96bea8c-8f0c-4cd2-8f91-0987dd342bf0","type":"DataRange1d"}},"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"397959a0-257c-4540-ae1a-6c289226d873","type":"Circle"},{"attributes":{"plot":null,"text":"Per capita CO2 emissions (metric tons of carbon)"},"id":"d00cf7cc-acb4-4101-aba2-3c664adde376","type":"Title"},{"attributes":{"callback":null},"id":"3c398ecb-a9fb-423f-9af0-6077f2dd6bde","type":"DataRange1d"},{"attributes":{},"id":"17b3575d-ed8d-4a63-890e-01ba2c879aff","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0ac2d413-dac3-4f92-87ed-91f4a530d6a8","type":"PanTool"},{"id":"82d222fb-5d9a-424e-8f80-c44efcc05186","type":"WheelZoomTool"},{"id":"2180f49d-da33-463d-8f98-d0094e2321bb","type":"BoxZoomTool"},{"id":"6b4f1dfb-fb2f-4760-9d8d-39a4e29c15ce","type":"SaveTool"},{"id":"d4e28d81-9f8e-400a-8d40-3e3096e299bc","type":"ResetTool"},{"id":"5b5ada68-6918-466d-b687-839e44de2bbe","type":"HelpTool"}]},"id":"27dcba1c-ff2f-44ec-ad58-4431b72dcd08","type":"Toolbar"},{"attributes":{"axis_label":"Year","formatter":{"id":"ebdf02a5-28d9-4a38-905d-74ffde5ec228","type":"BasicTickFormatter"},"plot":{"id":"4eaa5a7d-164e-44a7-9349-910c20727679","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c87646e-0507-40a9-840c-8c6eb6757433","type":"BasicTicker"}},"id" ...

# %%
from sklearn.svm import SVR

# %%
br_data = brasil[brasil.Year>1949]
X = br_data[x].values.reshape(-1, 1)
Y = br_data[y].values.reshape(-1, 1)

# %%
reg = SVR(kernel="linear")
results = reg.fit(X, Y).predict(X).reshape(-1,1)
# Out:
# /usr/lib/python3.6/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
p2 = figure(plot_width=500, plot_height=300, x_axis_label = x, title=y)
p2.scatter(brasil[x], brasil[y])
p2.line(x=br_data[x], y=results.tolist(), line_width=2, line_color="darkorange")
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="523cee1c-41a9-4dcd-8764-92f2a0c93cbe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("523cee1c-41a9-4dcd-8764-92f2a0c93cbe").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("523cee1c-41a9-4dcd-8764-92f2a0c93cbe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '523cee1c-41a9-4dcd-8764-92f2a0c93cbe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af3a68f2-1ad5-49a7-a411-d944cb5c5734":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5a2d25b6-8a60-4d26-8b32-4baec4508f89","type":"BoxAnnotation"},{"attributes":{"axis_label":"Year","formatter":{"id":"7028f42d-0b75-47fe-b181-fae8a0dc67df","type":"BasicTickFormatter"},"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"},"ticker":{"id":"5eb9f67a-83a9-44bc-86cc-6bd55c5e6ac8","type":"BasicTicker"}},"id":"8ea7d43f-647d-437b-93e4-b057e682730c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"33fcfabe-aeff-4645-acc3-dc27fb38fc3d","type":"ColumnDataSource"},"glyph":{"id":"01f295a2-f2ba-462a-ba2b-8e2a5396ca53","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"84ef009a-062c-4756-98e8-b5b49aff46c8","type":"Line"},"selection_glyph":null},"id":"c6da554c-116c-468a-934f-5569be3a7102","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"}},"id":"f0859dc3-2638-41e4-a896-9d242163f39d","type":"ResetTool"},{"attributes":{"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"}},"id":"5ddf63ac-8aa1-4cd1-81f8-2c891a4da4e1","type":"SaveTool"},{"attributes":{"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"}},"id":"e3271c0a-f250-4bb1-b491-7e313493c864","type":"HelpTool"},{"attributes":{"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"}},"id":"1c8cd706-6233-49cc-a340-062226705fea","type":"PanTool"},{"attributes":{"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"},"ticker":{"id":"5eb9f67a-83a9-44bc-86cc-6bd55c5e6ac8","type":"BasicTicker"}},"id":"f6d6795b-c84c-4d25-80c4-c836c844d35f","type":"Grid"},{"attributes":{},"id":"a89f27fa-5f2c-492c-920c-9b4da719c589","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"5a2d25b6-8a60-4d26-8b32-4baec4508f89","type":"BoxAnnotation"},"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"}},"id":"feb6240c-7dd6-4b15-bf3b-5b82b7983412","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"91733dc2-8301-4529-9b67-b5ec09e75868","type":"Circle"},{"attributes":{"callback":null},"id":"d00f3fed-26ec-47bf-bd08-4721fb174730","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"84ef009a-062c-4756-98e8-b5b49aff46c8","type":"Line"},{"attributes":{"formatter":{"id":"a89f27fa-5f2c-492c-920c-9b4da719c589","type":"BasicTickFormatter"},"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"},"ticker":{"id":"6590b6a4-33bd-4d65-b0bb-7af2765e9992","type":"BasicTicker"}},"id":"90751f1b-fb12-4f78-97e9-c725d8f30e6b","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"3350bdda-a628-4766-bf2e-e2995255d717","subtype":"Figure","type":"Plot"},"ticker":{"id":"6590b6a4-33bd-4d65-b0bb-7af2765e9992","type":"BasicTicker"}},"id":"1966a4f3-5bcd-4954-994a-1cd771031502","type":"Grid"},{"attributes":{},"id":"7028f42d-0b75-47fe-b181-fae8a0dc67df","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2 ...

# %%
country = "JAMAICA"
pais = data[data.Nation==country][[x, y]]

p3 = figure(plot_width=500,
    plot_height=300,
    x_axis_label = x,
    title = country+"--"+y)

p3.scatter(brasil[x], brasil[y], color="indigo", legend="BRASIL")
p3.scatter(pais[x], pais[y], color="darkorange", legend=country)

p3.legend.location="bottom_right"

show(p3)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1a490a90-ec3b-43e9-bb1e-96576093be2e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1a490a90-ec3b-43e9-bb1e-96576093be2e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1a490a90-ec3b-43e9-bb1e-96576093be2e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1a490a90-ec3b-43e9-bb1e-96576093be2e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3f7908cd-ce0b-4888-b6b9-6cbf9d6c426c":{"roots":{"references":[{"attributes":{"callback":null},"id":"9c0d9cfc-b112-4100-a1fd-01dfbdbcdbc7","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb70aedf-ed80-4672-9bfd-9bc61bf64b2b","type":"Circle"},{"attributes":{"axis_label":"Year","formatter":{"id":"53c3b976-f5a5-4841-8d9a-d3d396bf2e3e","type":"BasicTickFormatter"},"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d5f2f17-ab71-4e6b-bc68-ed54aca34b05","type":"BasicTicker"}},"id":"c8159c08-62d1-46a5-ac75-8cdb1e4c3f7c","type":"LinearAxis"},{"attributes":{"callback":null},"id":"ce0f7cd3-69a0-4205-83d3-66895696cfa5","type":"DataRange1d"},{"attributes":{},"id":"7d5f2f17-ab71-4e6b-bc68-ed54aca34b05","type":"BasicTicker"},{"attributes":{"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d5f2f17-ab71-4e6b-bc68-ed54aca34b05","type":"BasicTicker"}},"id":"e425dd97-a715-413c-9c94-ca436188e25e","type":"Grid"},{"attributes":{"formatter":{"id":"0252b143-8e52-4d52-88a1-8734d797a830","type":"BasicTickFormatter"},"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9076e499-d885-43e7-8d0e-6fa04a215858","type":"BasicTicker"}},"id":"9c7ea606-9d9e-4052-907c-b97e64577b77","type":"LinearAxis"},{"attributes":{},"id":"9076e499-d885-43e7-8d0e-6fa04a215858","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"},"ticker":{"id":"9076e499-d885-43e7-8d0e-6fa04a215858","type":"BasicTicker"}},"id":"6448dab4-764d-4a25-9ef5-c108e6e531f4","type":"Grid"},{"attributes":{"data_source":{"id":"134fc316-aabe-49f3-8c28-add83c3db564","type":"ColumnDataSource"},"glyph":{"id":"ace39535-1e85-4dc9-acb2-f55ea02f0344","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fb70aedf-ed80-4672-9bfd-9bc61bf64b2b","type":"Circle"},"selection_glyph":null},"id":"19346622-a88b-4b21-8257-51bb8c4b08a1","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"indigo"},"line_color":{"value":"indigo"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ace39535-1e85-4dc9-acb2-f55ea02f0344","type":"Circle"},{"attributes":{"items":[{"id":"c6e22923-d968-4c47-9534-d923ef2ffb46","type":"LegendItem"},{"id":"6833bf9d-57ef-49c8-a336-eb705c94f4b1","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"}},"id":"4774d86e-18a9-493d-8be2-cfc8d14146bc","type":"Legend"},{"attributes":{"plot":null,"text":"JAMAICA--Per capita CO2 emissions (metric tons of carbon)"},"id":"699512c7-1511-481b-8afe-00866f846daf","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"27dd4889-7064-489c-a596-dceb007bd481","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"}},"id":"f3317aed-4b16-45a9-a9d2-ece707f33332","type":"PanTool"},{"attributes":{},"id":"53c3b976-f5a5-4841-8d9a-d3d396bf2e3e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"}},"id":"2b9d249e-beb1-4680-b4f1-f979c83e87a2","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"27dd4889-7064-489c-a596-dceb007bd481","type":"BoxAnnotation"},"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0fb3e8","subtype":"Figure","type":"Plot"}},"id":"a984cb49-210a-437a-8961-15deaec738f7","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"aec8d00b-28af-40e4-a81c-eab49a0f ...
